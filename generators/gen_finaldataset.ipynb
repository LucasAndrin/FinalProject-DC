# %%
import pandas as pd

energy_path = '../data/generated/gen-electricity-sources.csv'
emissions_path = '../data/generated/gen-co2-emissions.csv'

energy = pd.read_csv(energy_path)
emissions = pd.read_csv(emissions_path)

# Filtrar colunas relevantes
emissions_cols = ['Entity', 'Year', 'Total (CO₂)', 'Coal (CO₂)', 'Oil (CO₂)', 'Gas (CO₂)']
energy_cols = ['Entity', 'Year', 'Coal (TWh)', 'Gas (TWh)', 'Oil (TWh)', 'Nuclear (TWh)', 'Hydro (TWh)', 'Solar (TWh)', 'Wind (TWh)']

merged = pd.merge(
    emissions[emissions_cols],
    energy[energy_cols],
    on=['Entity', 'Year'],
    how='inner'
)

merged.to_csv('../data/generated/final-dataset.csv', index=False)

# %%
merged
# Out:
#            Entity  Year   Total (CO₂)    Coal (CO₂)     Oil (CO₂)  \
# 0     Afghanistan  2000  1.047128e+06  3.664000e+03  7.877600e+05
# 1     Afghanistan  2001  1.069098e+06  6.961600e+04  7.621120e+05
# 2     Afghanistan  2002  1.340995e+06  5.510900e+04  7.274380e+05
# 3     Afghanistan  2003  1.559602e+06  9.181300e+04  9.915750e+05
# 4     Afghanistan  2004  1.237247e+06  9.160000e+04  9.086720e+05
# ...           ...   ...           ...           ...           ...
# 7448        World  2018  3.676660e+10  1.472503e+10  1.226732e+10
# 7449        World  2019  3.703980e+10  1.468410e+10  1.237789e+10
# 7450        World  2020  3.504654e+10  1.422572e+10  1.093896e+10
# 7451        World  2021  3.685799e+10  1.498281e+10  1.155595e+10
# 7452        World  2022  3.719184e+10  1.521879e+10  1.192040e+10
#
#          Gas (CO₂)  Coal (TWh)  Gas (TWh)  Oil (TWh)  Nuclear (TWh)  \
# 0     2.235040e+05        0.00       0.00       0.17           0.00
# 1     2.088480e+05        0.04       0.00       0.15           0.00
# 2     5.474160e+05        0.04       0.00       0.11           0.00
# 3     4.664080e+05        0.09       0.00       0.19           0.00
# 4     2.271680e+05        0.06       0.00       0.17           0.00
# ...            ...         ...        ...        ...            ...
# 7448  7.498006e+09    10028.19    6229.08     909.06        2658.70
# 7449  7.621401e+09     9821.41    6405.51     854.82        2754.08
# 7450  7.555247e+09     9437.11    6386.34     775.30        2648.37
# 7451  7.922053e+09    10154.13    6546.18     855.07        2762.24
# 7452  7.747787e+09    10263.17    6606.91     886.49        2639.85
#
#       Hydro (TWh)  Solar (TWh)  Wind (TWh)
# 0            0.31         0.00        0.00
# 1            0.50         0.00        0.00
# 2            0.56         0.00        0.00
# 3            0.63         0.00        0.00
# 4            0.56         0.00        0.00
# ...           ...          ...         ...
# 7448      4176.91       574.03     1268.00
# 7449      4228.71       704.40     1420.80
# 7450      4347.86       855.23     1591.37
# 7451      4287.90      1053.49     1856.65
# 7452      4321.15      1329.69     2106.93
#
# [7453 rows x 13 columns]
