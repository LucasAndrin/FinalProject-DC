# %%
import pandas as pd

dfghg = pd.read_csv('../data/ghg-emissions.csv')
dfghg
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1850
# 1      Afghanistan  AFG  1851
# 2      Afghanistan  AFG  1852
# 3      Afghanistan  AFG  1853
# 4      Afghanistan  AFG  1854
# ...            ...  ...   ...
# 37405     Zimbabwe  ZWE  2019
# 37406     Zimbabwe  ZWE  2020
# 37407     Zimbabwe  ZWE  2021
# 37408     Zimbabwe  ZWE  2022
# 37409     Zimbabwe  ZWE  2023
#
#        Annual greenhouse gas emissions in CO₂ equivalents
# 0                                              7435743.5
# 1                                              7499858.5
# 2                                              7560495.5
# 3                                              7619898.0
# 4                                              7678120.0
# ...                                                  ...
# 37405                                         34347856.0
# 37406                                         31322906.0
# 37407                                         33549390.0
# ...

# %%
# Pré-processamento das emissões de GEE
dfghg = dfghg.rename(columns={'Annual greenhouse gas emissions in CO₂ equivalents': 'GHG'})
dfghg = dfghg.drop(columns=['Code'])
dfghg.reset_index()
dfghg.to_csv('../data/generated/gen-ghg-emissions.csv', index=False)
# Out:
# np.float64(53816852000.0)
